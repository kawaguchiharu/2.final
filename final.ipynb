# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
#スクレイピングしたデータから必要なデータ
df = pd.read_csv("ac_d.csv")
df
# Out:
#                  Doing  Daytime
# 0  While driving a car   162842
# 1  Riding a motorcycle    15338
# 2       Riding a moped    11371
# 3     Riding a bicycle    53550
# 4        While walking    23420
# 5                 else      416

# %%
#昼間
labels = df['Doing']
sizes = df['Daytime']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Daytime')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()

# %%
#スクレイピングしたデータから必要なデータ
df0 = pd.read_csv("ac_n.csv")
df0
# Out:
#                  Doing  Nighttime
# 0  While driving a car      50536
# 1  Riding a motorcycle       7575
# 2       Riding a moped       4661
# 3     Riding a bicycle      14590
# 4        While walking      14775
# 5                 else        137

# %%
#夜間
labels = df0['Doing']
sizes = df0['Nighttime']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Nighttime')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()

# %%
#アンケート結果(朝)
df1 = pd.read_csv("morning.csv")
df1
# Out:
#            cause  value
# 0           road      5
# 1   street light      0
# 2  traffic light      3
# 3       sunlight      2
# 4        unknown     13

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
labels = df1['cause']
sizes = df1['value']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('morning')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()

# %%
#アンケート結果(昼)
df2 = pd.read_csv("noon.csv")
df2
# Out:
#            cause  value
# 0           road      3
# 1   street light      0
# 2  traffic light      0
# 3       sunlight      5
# 4        unknown     15

# %%
labels = df2['cause']
sizes = df2['value']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('noon')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()

# %%
#アンケート結果(夕方)
df3 = pd.read_csv("evening.csv")
df3
# Out:
#            cause  value
# 0           road      4
# 1   street light      5
# 2  traffic light      2
# 3       sunlight      3
# 4        unknown     17

# %%
labels = df3['cause']
sizes = df3['value']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('evining')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()

# %%
#アンケート結果(夜)
df4 = pd.read_csv("night.csv")
df4
# Out:
#            cause  value
# 0           road      2
# 1   street light     18
# 2  traffic light      1
# 3       sunlight      0
# 4        unknown     19

# %%
labels = df4['cause']
sizes = df4['value']

# 円グラフの描画
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('night')
plt.axis('equal')  # アスペクト比を保つために必要

# グラフの表示
plt.show()
